# %%
import pandas as pd
import mne
from mne.datasets import sample
from mne.io import Raw
import matplotlib.pyplot as plt

# %%
data_path = sample.data_path() # neuroimaging data

# %%
print(data_path)
# Out:
# /Users/kvebers/mne_data/MNE-sample-data

# %%
raw_file = data_path / 'MEG/sample/sample_audvis_raw.fif'
raw = mne.io.read_raw_fif(str(raw_file), preload=True)
# Out:
# Opening raw data file /Users/kvebers/mne_data/MNE-sample-data/MEG/sample/sample_audvis_raw.fif...
#     Read a total of 3 projection items:
#         PCA-v1 (1 x 102)  idle
#         PCA-v2 (1 x 102)  idle
#         PCA-v3 (1 x 102)  idle
#     Range : 25800 ... 192599 =     42.956 ...   320.670 secs
# Ready.
# Reading 0 ... 166799  =      0.000 ...   277.714 secs...

# %%
print(raw)
# Out:
# <Raw | sample_audvis_raw.fif, 376 x 166800 (277.7 s), ~481.8 MB, data loaded>

# %%
raw.plot(n_channels=1, duration=10, start=0) # this is how a single channal looks like
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 5 Axes>
# <MNEBrowseFigure size 800x800 with 5 Axes>

# %%
raw.plot(n_channels=40, duration=10, start=0) # this is how 40 channals look like
# Out:
# <MNEBrowseFigure size 800x800 with 5 Axes>
# <MNEBrowseFigure size 800x800 with 5 Axes>

# %%
raw_filtered = raw.copy().filter(l_freq=8., h_freq=30.) # filtering from 8 to 40 , not good tho
# 8-12 Hz (Mu band): Relax
# 13 - 30 Hz (Beta band): Active Thinking
# 31 - 40 (Low Gamma Band) High Mental Activity
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 993 samples (1.653 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  71 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done 161 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done 287 tasks      | elapsed:    1.2s

# %%
print(raw_filtered)
# Out:
# <Raw | sample_audvis_raw.fif, 376 x 166800 (277.7 s), ~481.8 MB, data loaded>

# %%
raw_filtered.plot(n_channels=40, duration=10, start=0) # this is how 40 channals look like
# Out:
# <MNEBrowseFigure size 800x800 with 5 Axes>
# <MNEBrowseFigure size 800x800 with 5 Axes>

# %%
raw.plot_sensors(show_names=True)

# %%
raw.plot_sensors(kind='3d')

# %%
print(raw.info)
# Out:
# <Info | 21 non-empty values
#  acq_pars: ACQch001 110113 ACQch002 110112 ACQch003 110111 ACQch004 110122 ...
#  bads: 2 items (MEG 2443, EEG 053)
#  ch_names: MEG 0113, MEG 0112, MEG 0111, MEG 0122, MEG 0123, MEG 0121, MEG ...
#  chs: 204 Gradiometers, 102 Magnetometers, 9 Stimulus, 60 EEG, 1 EOG
#  custom_ref_applied: False
#  description: acquisition (megacq) VectorView system at NMR-MGH
#  dev_head_t: MEG device -> head transform
#  dig: 146 items (3 Cardinal, 4 HPI, 61 EEG, 78 Extra)
#  events: 1 item (list)
#  experimenter: MEG
#  file_id: 4 items (dict)
#  highpass: 0.1 Hz
#  hpi_meas: 1 item (list)
#  hpi_results: 1 item (list)
#  lowpass: 172.2 Hz
#  meas_date: 2002-12-03 19:01:10 UTC
#  meas_id: 4 items (dict)
#  nchan: 376
#  proj_id: 1 item (ndarray)
#  proj_name: test
#  projs: PCA-v1: off, PCA-v2: off, PCA-v3: off
#  sfreq: 600.6 Hz
# >

# %%
raw.plot_sensors(kind='3d', show_names='True')

# %%
# Out:
# <MNEBrowseFigure size 800x800 with 5 Axes>

# %%
psds, freqs = mne.time_frequency.psd_welch(raw_filtered, fmin=1, fmax=40, n_fft=2048)

# Plot PSD
plt.figure(figsize=(10, 6))
plt.semilogy(freqs, psds.T)
plt.xlabel('Frequency (Hz)')
plt.ylabel('Power Spectral Density (dB)')
plt.title('Power Spectral Density')
plt.show()

# Extract features for each channel
features = np.log(psds.mean(axis=1))

# Print features for the first few channels
print(features[:10])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 psds, freqs = mne.time_frequency.psd_welch(raw_filtered, fmin=1, fmax=40, n_fft=2048)
#       3 # Plot PSD
#       4 plt.figure(figsize=(10, 6))
#
# File ~/projects/Total-perspective-vortex/venv/lib/python3.9/site-packages/lazy_loader/__init__.py:94, in attach.<locals>.__getattr__(name)
#      92     return attr
#      93 else:
# ---> 94     raise AttributeError(f"No {package_name} attribute {name}")
#
# AttributeError: No mne.time_frequency attribute psd_welch
